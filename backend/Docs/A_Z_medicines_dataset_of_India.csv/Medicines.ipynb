# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Medicines.csv")
df.head()
# Out:
#    id                      name  price(₹)  Is_discontinued  \
# 0   1  Augmentin 625 Duo Tablet    223.42            False
# 1   2       Azithral 500 Tablet    132.36            False
# 2   3          Ascoril LS Syrup    118.00            False
# 3   4      Allegra 120mg Tablet    218.81            False
# 4   5            Avil 25 Tablet     10.96            False
#
#                       manufacturer_name       type         pack_size_label  \
# 0  Glaxo SmithKline Pharmaceuticals Ltd  allopathy     strip of 10 tablets
# 1           Alembic Pharmaceuticals Ltd  allopathy      strip of 5 tablets
# 2          Glenmark Pharmaceuticals Ltd  allopathy  bottle of 100 ml Syrup
# 3                     Sanofi India  Ltd  allopathy     strip of 10 tablets
# 4                     Sanofi India  Ltd  allopathy     strip of 15 tablets
#
#       short_composition1          short_composition2
# 0  Amoxycillin  (500mg)      Clavulanic Acid (125mg)
# ...

# %%
df.tail()
# Out:
#             id                           name  price(₹)  Is_discontinued  \
# 253968  253969  Ziyapod 100mg Oral Suspension      62.3            False
# 253969  253970            Zemhart 30mg Tablet      54.0            False
# 253970  253971              Zivex 25mg Tablet      57.0            False
# 253971  253972        ZI Fast 500mg Injection     152.0            False
# 253972  253973      Zyvocol 1% Dusting Powder     110.0            False
#
#                             manufacturer_name       type  \
# 253968            Ziyana Lifesciences Pvt Ltd  allopathy
# 253969                 Leeford Healthcare Ltd  allopathy
# 253970                          Euro Organics  allopathy
# 253971  Burgeon Health Series Private Limited  allopathy
# 253972                         GBK Healthcare  allopathy
#
#                         pack_size_label            short_composition1  \
# 253968  bottle of 30 ml Oral Suspension  Cefpodoxime Proxetil (100mg)
# ...

# %%
df.describe()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253973 entries, 0 to 253972
# Data columns (total 9 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  253973 non-null  int64
#  1   name                253973 non-null  object
#  2   price(₹)            253973 non-null  float64
#  3   Is_discontinued     253973 non-null  bool
#  4   manufacturer_name   253973 non-null  object
#  5   type                253973 non-null  object
#  6   pack_size_label     253973 non-null  object
#  7   short_composition1  253973 non-null  object
#  8   short_composition2  112171 non-null  object
# dtypes: bool(1), float64(1), int64(1), object(6)
# memory usage: 15.7+ MB

# %%
df.isna().sum()
# Out:
# id                         0
# name                       0
# price(₹)                   0
# Is_discontinued            0
# manufacturer_name          0
# type                       0
# pack_size_label            0
# short_composition1         0
# short_composition2    141802
# dtype: int64

# %%
# df.drop("short_composition1",axis=1,inplace=True)
df.drop("id",axis=1,inplace=True)

# %%
df.drop("short_composition2",axis=1,inplace=True)

# %%
df = df[df['Is_discontinued'] == False]

# %%
df
# Out:
#                                  name  price(₹)  Is_discontinued  \
# 0            Augmentin 625 Duo Tablet    223.42            False
# 1                 Azithral 500 Tablet    132.36            False
# 2                    Ascoril LS Syrup    118.00            False
# 3                Allegra 120mg Tablet    218.81            False
# 4                      Avil 25 Tablet     10.96            False
# ...                               ...       ...              ...
# 253968  Ziyapod 100mg Oral Suspension     62.30            False
# 253969            Zemhart 30mg Tablet     54.00            False
# 253970              Zivex 25mg Tablet     57.00            False
# 253971        ZI Fast 500mg Injection    152.00            False
# 253972      Zyvocol 1% Dusting Powder    110.00            False
#
#                             manufacturer_name       type  \
# 0        Glaxo SmithKline Pharmaceuticals Ltd  allopathy
# 1                 Alembic Pharmaceuticals Ltd  allopathy
# ...

# %%
num_duplicates = df.duplicated().sum()
print(f"Number of duplicated rows: {num_duplicates}")
# Out:
# Number of duplicated rows: 7

# %%
duplicated_rows = df[df.duplicated(keep=False)]
print(duplicated_rows)
# Out:
#                          name  price(₹)  Is_discontinued  \
# 58929   Doloneuron 300 Tablet    171.00            False
# 62762   Doloneuron 300 Tablet    171.00            False
# 113980     Jimlig 100 Capsule    189.00            False
# 114244     Jimlig 100 Capsule    189.00            False
# 133498  Mefkind-DS Suspension     45.98            False
# 134616  Mefkind-DS Suspension     45.98            False
# 162144   Oxmazetol 150 Tablet     79.59            False
# 166400   Oxmazetol 150 Tablet     79.59            False
# 192983       Rexfen-TH Tablet    230.00            False
# 196832       Rexfen-TH Tablet    230.00            False
# 216392  Tampil 0.4 Capsule PR     99.00            False
# 217089  Tampil 0.4 Capsule PR     99.00            False
# 241438       Wincold Z Tablet     36.00            False
# 241473       Wincold Z Tablet     36.00            False
#
#                   manufacturer_name       type             pack_size_label  \
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.drop("Is_discontinued",axis=1,inplace=True)

# %%
num_duplicates = df.duplicated().sum()
print(f"Number of duplicated rows: {num_duplicates}")
# Out:
# Number of duplicated rows: 0

# %%
df.to_csv("Transformeddataset.csv")

# %%
df.value_counts()
# Out:
# name                               price(₹)  manufacturer_name                type       pack_size_label            short_composition1
# A 1 5mg Tablet                     12.33     Patson Laboratories Pvt  Ltd     allopathy  strip of 10 tablets        Amlodipine (5mg)                1
# Onduro 4mg Injection               23.80     Ikon Remedies Pvt Ltd            allopathy  ampoule of 4 ml Injection  Ondansetron (4mg/2ml)           1
# Onilox 200mg Tablet                50.00     Knox Life Sciences Pvt Ltd       allopathy  strip of 10 tablets        Ofloxacin (200mg)               1
# Onim 100mg Tablet                  10.00     Kaleon Laboratories              allopathy  strip of 10 tablets        Nimesulide (100mg)              1
# Onimar 150mg Tablet                20.12     Emcee Pharmaceuticals Pvt Ltd    allopathy  strip of 10 tablets        Theophylline (150mg)            1
# ...

# %%
grouped_df = df.groupby('manufacturer_name')
print(grouped_df)

# %%
grouped_df.head()
# Out:
#             id                            name  price(₹)  \
# 0            1        Augmentin 625 Duo Tablet    223.42
# 1            2             Azithral 500 Tablet    132.36
# 2            3                Ascoril LS Syrup    118.00
# 3            4            Allegra 120mg Tablet    218.81
# 4            5                  Avil 25 Tablet     10.96
# ...        ...                             ...       ...
# 253348  253349  Zexorab D 30mg/20mg Capsule SR     95.00
# 253362  253363            Zeemox 250mg Capsule     43.70
# 253552  253553         Zepodoz 200mg Tablet DT     84.00
# 253812  253813          Zebicof-LS Expectorant     85.00
# 253967  253968       Zef CV 200mg/125mg Tablet    260.00
#
#                            manufacturer_name       type  \
# 0       Glaxo SmithKline Pharmaceuticals Ltd  allopathy
# 1                Alembic Pharmaceuticals Ltd  allopathy
# 2               Glenmark Pharmaceuticals Ltd  allopathy
# ...

# %%
groupedbytype=df.groupby("type")
groupedbytype.head()
# Out:
#    id                      name  price(₹)  \
# 0   1  Augmentin 625 Duo Tablet    223.42
# 1   2       Azithral 500 Tablet    132.36
# 2   3          Ascoril LS Syrup    118.00
# 3   4      Allegra 120mg Tablet    218.81
# 4   5            Avil 25 Tablet     10.96
#
#                       manufacturer_name       type         pack_size_label
# 0  Glaxo SmithKline Pharmaceuticals Ltd  allopathy     strip of 10 tablets
# 1           Alembic Pharmaceuticals Ltd  allopathy      strip of 5 tablets
# 2          Glenmark Pharmaceuticals Ltd  allopathy  bottle of 100 ml Syrup
# 3                     Sanofi India  Ltd  allopathy     strip of 10 tablets
# 4                     Sanofi India  Ltd  allopathy     strip of 15 tablets

# %%
groupedbytype.tail()
# Out:
#             id                           name  price(₹)  \
# 253968  253969  Ziyapod 100mg Oral Suspension      62.3
# 253969  253970            Zemhart 30mg Tablet      54.0
# 253970  253971              Zivex 25mg Tablet      57.0
# 253971  253972        ZI Fast 500mg Injection     152.0
# 253972  253973      Zyvocol 1% Dusting Powder     110.0
#
#                             manufacturer_name       type  \
# 253968            Ziyana Lifesciences Pvt Ltd  allopathy
# 253969                 Leeford Healthcare Ltd  allopathy
# 253970                          Euro Organics  allopathy
# 253971  Burgeon Health Series Private Limited  allopathy
# 253972                         GBK Healthcare  allopathy
#
#                         pack_size_label
# 253968  bottle of 30 ml Oral Suspension
# 253969              strip of 10 tablets
# 253970              strip of 10 tablets
# 253971              vial of 1 Injection
# 253972   bottle of 75 gm Dusting Powder

# %%
df.nunique()
# Out:
# id                   246068
# name                 241990
# price(₹)              19914
# manufacturer_name      7641
# type                      1
# pack_size_label        1833
# dtype: int64

# %%
unique_types = df['type'].unique()
print(unique_types)
# Out:
# ['allopathy']
